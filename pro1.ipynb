head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-10-06  120.769997  121.529999  119.500000  120.300003  120.300003
# 1  2022-10-07  118.000000  118.169998  113.879997  114.559998  114.559998
# 2  2022-10-10  115.099998  116.250000  112.430000  113.669998  113.669998
# 3  2022-10-11  112.709999  115.480003  110.389999  112.209999  112.209999
# 4  2022-10-12  112.489998  113.830002  111.400002  112.900002  112.900002
#
#      Volume
# 0  42253800
# 1  54678000
# 2  42339700
# 3  56432200
# 4  45728700

# %%
AMZN['Company']='Amazon'
AMZN.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-10-06  120.769997  121.529999  119.500000  120.300003  120.300003
# 1  2022-10-07  118.000000  118.169998  113.879997  114.559998  114.559998
# 2  2022-10-10  115.099998  116.250000  112.430000  113.669998  113.669998
# 3  2022-10-11  112.709999  115.480003  110.389999  112.209999  112.209999
# 4  2022-10-12  112.489998  113.830002  111.400002  112.900002  112.900002
#
#      Volume Company
# 0  42253800  Amazon
# 1  54678000  Amazon
# 2  42339700  Amazon
# 3  56432200  Amazon
# 4  45728700  Amazon

# %%
stocks=pd.concat([AAPL,AMZN,GOOGL,MSFT])
stocks.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  06-10-2022  145.809998  147.539993  145.220001  145.429993  144.572342
# 1  07-10-2022  142.539993  143.100006  139.449997  140.089996  139.263840
# 2  10-10-2022  140.419998  141.889999  138.570007  140.419998  139.591888
# 3  11-10-2022  139.899994  141.350006  138.220001  138.979996  138.160370
# 4  12-10-2022  139.130005  140.360001  138.160004  138.339996  137.524139
#
#      Volume Company
# 0  68402200   Apple
# 1  85925600   Apple
# 2  74899000   Apple
# 3  77033700   Apple
# 4  70433700   Apple

# %%
stocks.to_csv('Stocks.csv',index=False)

# %%
stocks.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1004.000000  1004.000000  1004.000000  1004.000000  1004.000000
# mean    167.038835   169.018128   165.206534   167.158456   166.774041
# std      76.071879    76.689602    75.462932    76.085495    75.734447
# min      82.800003    83.480003    81.430000    81.820000    81.820000
# 25%     105.027500   106.337499   103.862501   105.255001   105.255001
# 50%     136.985001   138.465004   135.110001   137.095001   137.095001
# 75%     201.567504   203.774998   199.817498   200.899998   200.188805
# max     361.750000   366.779999   352.440002   359.489990   358.730469
#
#              Volume
# count  1.004000e+03
# mean   4.858165e+07
# std    2.612747e+07
# min    9.200800e+06
# 25%    2.764710e+07
# 50%    4.446440e+07
# 75%    6.213605e+07
# max    2.231334e+08

# %% [markdown]
# # Perform cleaning

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1004 entries, 0 to 250
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1004 non-null   object
#  1   Open       1004 non-null   float64
#  2   High       1004 non-null   float64
#  3   Low        1004 non-null   float64
#  4   Close      1004 non-null   float64
#  5   Adj Close  1004 non-null   float64
#  6   Volume     1004 non-null   int64
#  7   Company    1004 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 70.6+ KB

# %%
stocks.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Company      0
# dtype: int64

# %%
stocks.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # What was the change in stock price over time?

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplot

import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
Companies = stocks['Company'].drop_duplicates().values
print(Companies)
# Out:
# ['Apple' 'Amazon' 'Google' 'Microsoft']

# %%
# Group the DataFrame by 'Company'.
grouped = stocks.groupby('Company')

# Create a figure and axis.
fig, ax = plt.subplots(figsize=(15, 7))

# List of companies (assuming you have it defined somewhere).
Companies = list(grouped.groups.keys())

# Plot each company's 'Adj Close' data.
for comp in Companies:
    stock = grouped.get_group(comp)
    stock['Adj Close'].plot(legend=True, ax=ax, label=comp)

# Add a legend.
ax.legend()

# Show the plot.
plt.show()

# %%
max_High = stock['High'].max()
max_High_index = stock['High'].idxmax()

print('Maximum volume:',max_High)
print('Index of maximum volume:', max_High_index)
# Out:
# Maximum volume: 366.779999
# Index of maximum volume: 194

# %%
min_Low = stock['Low'].min()
min_Low_index = stock['Low'].idxmin()

print('Minimum volume:', min_Low)
print('Index of minimum volume:', min_Low_index)
# Out:
# Minimum volume: 213.429993
# Index of minimum volume: 21

# %% [markdown]
# # Visualize the change in a stock’s volume being traded, over time

# %%
AMZN['Volume'].plot(legend=True,figsize=(12,5),title = "Amazon's Stock Trend")
# Out:
# <Axes: title={'center': "Amazon's Stock Trend"}>

# %%
#Plotting the stock's adjusted closing price using pandas
MSFT['Volume'].plot(legend=True,figsize=(12,5),title = "Microsoft's Stock Trend")
# Out:
# <Axes: title={'center': "Microsoft's Stock Trend"}>

# %%
#Plotting the stock's adjusted closing price using pandas
AAPL['Volume'].plot(legend=True,figsize=(12,5),title = " Stock Trend")
# Out:
# <Axes: title={'center': ' Stock Trend'}>

# %%
GOOGL['Volume'].plot(legend=True,figsize=(12,5),title = " Stock Trend")
# Out:
# <Axes: title={'center': ' Stock Trend'}>

# %% [markdown]
# # What was the moving average of various stocks?

# %%
AMZN.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 246  2023-09-29  128.199997  129.149994  126.320000  127.120003  127.120003
# 247  2023-10-02  127.279999  130.470001  126.540001  129.460007  129.460007
# 248  2023-10-03  128.059998  128.520004  124.250000  124.720001  124.720001
# 249  2023-10-04  126.059998  127.360001  125.680000  127.000000  127.000000
# 250  2023-10-05  126.709999  126.730003  124.330002  125.959999  125.959999
#
#        Volume Company
# 246  62377600  Amazon
# 247  48029700  Amazon
# 248  51565000  Amazon
# 249  44203900  Amazon
# 250  39634300  Amazon

# %%
AMZN[['Adj Close','MA for 20 days','MA for 50 days','MA for 100 days']].plot(subplots=False,figsize=(12,5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 AMZN[['Adj Close','MA for 20 days','MA for 50 days','MA for 100 days']].plot(subplots=False,figsize=(12,5))
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6178, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['MA for 20 days', 'MA for 50 days', 'MA for 100 days'] not in index"

# %% [markdown]
# # Interference
# Moving averages for more days have a smoother plot, as they’re less reliable on daily fluctuations. Still we can see that Amazon’s stock wahas been seeing a slight dip this year.

# %% [markdown]
# # What was the daily return average of a stock?

# %%
#The daily return column can be created by using the percentage change over the adjusted closing price
AMZN['Daily Return'] = AMZN['Adj Close'].pct_change()

# %%
AMZN['Daily Return'].tail()
# Out:
# 246    0.009049
# 247    0.018408
# 248   -0.036614
# 249    0.018281
# 250   -0.008189
# Name: Daily Return, dtype: float64

# %%
#Plotting the daily return
AMZN['Daily Return'].plot(figsize=(14,5),legend=True)
# Out:
# <Axes: >

# %%
f,ax=plt.subplots(figsize=(20,10))
sns.distplot(AMZN['Daily Return'].dropna(),bins=100,color='red',kde=False,ax=ax)
# Out:
# C:\Users\as551\AppData\Local\Temp\ipykernel_5204\4081542288.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(AMZN['Daily Return'].dropna(),bins=100,color='red',kde=False,ax=ax)
# <Axes: xlabel='Daily Return'>

# %% [markdown]
# # Inference:
# Positive daily returns are almost as frequent as negative returns for Amazon currently.
#
# Add a new column ‘Trend’ whose values are based on the 'Daily Return

# %%
def trend(x):
  if x > -0.015 and x <= 0.015:
    return 'Slight or No change'
  elif x > 0.015 and x <= 0.04:
    return 'Slight Positive'
  elif x < -0.015 and x >= -0.4:
    return 'Slight Negative'
  elif x > 0.04 and x <= 0.06:
    return 'Positive'
  elif x < -0.04 and x >= -0.06:
    return 'Negative'
  elif x > 0.06 and x <= 0.07:
    return 'Among top gainers'
  elif x < -0.06 and x >= -0.07:
    return 'Among top losers'
  elif x > 0.07:
    return 'Bull run'
  elif x <= -0.07:
    return 'Bear drop'
AMZN['Trend']= np.zeros(AMZN['Daily Return'].count()+1)
AMZN['Trend']= AMZN['Daily Return'].apply(lambda x:trend(x))
AMZN.tail(5)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 246  2023-09-29  128.199997  129.149994  126.320000  127.120003  127.120003
# 247  2023-10-02  127.279999  130.470001  126.540001  129.460007  129.460007
# 248  2023-10-03  128.059998  128.520004  124.250000  124.720001  124.720001
# 249  2023-10-04  126.059998  127.360001  125.680000  127.000000  127.000000
# 250  2023-10-05  126.709999  126.730003  124.330002  125.959999  125.959999
#
#        Volume Company  Daily Return                Trend
# 246  62377600  Amazon      0.009049  Slight or No change
# 247  48029700  Amazon      0.018408      Slight Positive
# 248  51565000  Amazon     -0.036614      Slight Negative
# 249  44203900  Amazon      0.018281      Slight Positive
# 250  39634300  Amazon     -0.008189  Slight or No change

# %% [markdown]
# # We can visualize to see how the stock was performing for past and this year using a Pie chart
#
# Visualize the trend frequency through a Pie Chart

# %%
labels=AMZN.Trend.value_counts().index
colors=["olive","orange","hotpink","slateblue","y","lime"]
sizes=AMZN.Trend.value_counts().values
plt.figure(figsize=(9,9))
plt.pie(sizes,labels=labels,colors=colors,autopct="%1.1f%%")
plt.title("Trend Frequency using a Pie Chart",color="saddlebrown",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Trend Frequency using a Pie Chart')

# %% [markdown]
# # Interference
# The Amazon stock was in the bull run for just about 0.4% of the time,for about 3.2% of the time period, the stock has performed positively on a given day. Likewise, for most period of time (about 60.6%) the stock showed a very slight or no change in the price.
#
# What was the correlation between daily returns of different stocks?
# Merging the columns of all companies Adjacent close

# %%
all_adj = pd.concat([AAPL['Adj Close'] ,GOOGL['Adj Close'],AMZN['Adj Close'],MSFT['Adj Close']], axis = 1)

# %%
all_adj.columns = ['Apple','Google','Amazon','Microsoft']

# %%
all_adj
# Out:
#           Apple      Google      Amazon   Microsoft
# 0    144.572342  101.419998  120.300003  244.428604
# 1    139.263840   98.680000  114.559998  231.998703
# 2    139.591888   97.860001  113.669998  227.056458
# 3    138.160370   97.180000  112.209999  223.253204
# 4    137.524139   97.559998  112.900002  223.589951
# ..          ...         ...         ...         ...
# 246  171.210007  130.860001  127.120003  315.750000
# 247  173.750000  134.169998  129.460007  321.799988
# 248  172.399994  132.429993  124.720001  313.390015
# 249  173.660004  135.240005  127.000000  318.959991
# 250  174.910004  135.070007  125.959999  319.359985
#
# [251 rows x 4 columns]

# %%
pct_df = all_adj.pct_change()
pct_df.tail()
# Out:
#         Apple    Google    Amazon  Microsoft
# 246  0.003046 -0.010959  0.009049   0.006727
# 247  0.014836  0.025294  0.018408   0.019161
# 248 -0.007770 -0.012969 -0.036614  -0.026134
# 249  0.007309  0.021219  0.018281   0.017773
# 250  0.007198 -0.001257 -0.008189   0.001254

# %%
f,ax=plt.subplots(figsize=(10,5))
sns.heatmap(pct_df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Inference:
# Microsoft seems to have the highest correlation with Apple as well as Google. But another interesting thing to note is that all tech companies that we explored are positively correlated.
